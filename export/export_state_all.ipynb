# %% [markdown]
# # This notebook reads in processed FAC data and exports a CSV file of all audits for a given state

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import re
from collections import Counter


# Select state
state = 'HI'


# FAC data
path = '/data/ihwang/data_journalism/allfac'
general_df = pd.read_pickle(path + '/processed/general.pkl')
# Export dataframe
state_df = general_df[general_df['STATE'] == state].copy()
state_df.to_csv(path + '/export/FAC_%s.csv' %state, index=False)

# %%
state_df.head()
# Out:
#         DBKEY  AUDITYEAR STATE CPASTATE    CPAPHONE TYPEOFENTITY  \
# 52358  126455       1998    HI       HI  8085419332
# 52359  126455       1999    HI       HI  8085419332
# 52360  126455       2000    HI       HI  8085317286
# 52361  126455       2001    HI       HI  8085317286          909
# 52362  126455       2002    HI       HI  8085317286          909
#
#       OVERSIGHTAGENCY  TOTFEDEXPEND REPORTABLECONDITION MATERIALWEAKNESS  \
# 52358              43       2782370                   N
# 52359              43       7832546                   N
# 52360              43       9236123                   N
# 52361              43       6824216                   N
# 52362              43       5664555                   N
#
#          ...     CPAFIRMNAME        CPACONTACT CPATITLE  ZIPCODE CPAZIPCODE  \
# 52358    ...        KPMG LLP  RALPH T KANETOKU  PARTNER  96743.0    96813.0
# 52359    ...        KPMG LLP  RALPH T KANETOKU  PARTNER  96743.0    96813.0
# ...
