# %% [markdown]
# # This notebook reads in processed FAC data and exports a CSV file of HI audits

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import re
from collections import Counter


# FAC data
file_names = ['findings', 'general']
[findings_df, general_df]  = [
    pd.read_pickle(processed_path + '%s.pkl' %file_name) for file_name in file_names
]


state = 'HI'


# Export general dataframe
state_df = general_df[general_df['STATE'] == state].copy()
# state_df.to_csv(processed_path + 'FAC_%s.csv' %state, index=False)

# %%
entity_df.head()
# Out:
#         DBKEY  AUDITYEAR STATE CPASTATE TYPEOFENTITY OVERSIGHTAGENCY  \
# 51251  126455       1998    HI       HI                           43
# 51252  126455       1999    HI       HI                           43
# 51253  126455       2000    HI       HI                           43
# 51254  126455       2001    HI       HI          909              43
# 51255  126455       2002    HI       HI          909              43
#
#        TOTFEDEXPEND                                       AUDITEENAME  \
# 51251       2782370  CALIFORNIA ASSOCIATION FOR RESEARCH IN ASTRONOMY
# 51252       7832546  CALIFORNIA ASSOCIATION FOR RESEARCH IN ASTRONOMY
# 51253       9236123  CALIFORNIA ASSOCIATION FOR RESEARCH IN ASTRONOMY
# 51254       6824216  CALIFORNIA ASSOCIATION FOR RESEARCH IN ASTRONOMY
# 51255       5664555  CALIFORNIA ASSOCIATION FOR RESEARCH IN ASTRONOMY
#
#       CPAFIRMNAME  ZIPCODE  CPAZIPCODE TYPEREPORT_FS TYPEREPORT_MP     CITY  \
# ...
